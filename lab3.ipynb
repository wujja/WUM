# %%
p = 3
def z(x,y):
  return (x-1)**2 + (y-2)**2

z(2,3)
z(1.8, 2.8)
# Out:
# 1.2799999999999998

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits import mplot3d

# %matplotlib inline
npoints = 30
limit = 8

x = np.linspace(-limit, limit, npoints)
y = np.linspace(-limit, limit, npoints)
X, Y = np.meshgrid(x, y)
Z = z(X, Y)
fig = plt.figure()
ax = plt.axes(projection = '3d')
ax.contour3D(X,Y,Z,40, cmap= 'winter')
# Out:
# /usr/local/lib/python3.7/dist-packages/mpl_toolkits/mplot3d/art3d.py:304: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self._segments3d = np.asanyarray(segments)

# %%
import tensorflow as tf

x = tf.Variable(2.)
y = tf.Variable(3.)

with tf.GradientTape() as tape:
  z = (x-1)**2 + (y-2)**2


gz = tape.gradient(z, (x, y))
gz
# Out:
# (<tf.Tensor: shape=(), dtype=float32, numpy=2.0>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=2.0>)

# %%
#z losowego symulacja 10x od losowego punktu punkt poczatkowy epsilon i czy maleje
